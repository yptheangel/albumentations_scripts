# %% [markdown]
# ## Use albumentations library for image augmentation
# To generate object detection dataset. Currently works for Pascal VOC format

# %% [markdown]
# Notebook author: yptheangel(Choo Wilson)
#
# References:<br>
# https://www.curiousily.com/posts/image-data-augmentation-for-tensorflow-2-keras-and-pytorch-with-albumentations-in-python/
# https://github.com/albumentations-team/albumentations_examples/blob/master/notebooks/example_bboxes.ipynb

# %%
# %matplotlib inline
import cv2
import os
import os.path as osp
import xml.etree.ElementTree as ET
import numpy as np
import albumentations as A
from albumentations import (Compose,BboxParams)
from matplotlib import pyplot as plt

# %%
def getObjects(fullname):
    CLS=['avocado','banana']
    bb = ""
    objs=[]
    cls_ids=[]
    in_file = open(fullname)
    tree=ET.parse(in_file)
    root = tree.getroot()
    # iterate through the objects inside a xml file
    for i, obj in enumerate(root.iter('object')):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in CLS or int(difficult)==1:
            continue
        cls_id = CLS.index(cls)
        xmlbox = obj.find('bndbox')
        b = [int(xmlbox.find('xmin').text), int(xmlbox.find('ymin').text), int(xmlbox.find('xmax').text), int(xmlbox.find('ymax').text)]
        c_id = cls_id
        objs.append(b)
        cls_ids.append(c_id)
    return objs,cls_ids

# %%
# Functions to visualize bounding boxes and class labels on an image. 
# Based on https://github.com/facebookresearch/Detectron/blob/master/detectron/utils/vis.py

BOX_COLOR = (0, 200,0)
TEXT_COLOR = (0, 0, 0)

def visualize_bbox(img, bbox, class_id, class_idx_to_name, color=BOX_COLOR, thickness=2):
#     x_min, y_min, w, h = bbox
    x_min, y_min, x_max, y_max = bbox
    cv2.rectangle(img, (int(x_min), int(y_min)), (int(x_max), int(y_max)), color=color, thickness=thickness)
    class_name = class_idx_to_name[class_id]
    ((text_width, text_height), _) = cv2.getTextSize(class_name, cv2.FONT_HERSHEY_SIMPLEX, 0.35, 1)    
    cv2.rectangle(img, (int(x_min), int(y_min - int(1.3 * text_height))), (int(x_min + text_width), int(y_min)), BOX_COLOR, -1)
    cv2.putText(img, class_name, (int(x_min), int(y_min - int(0.3 * text_height))), cv2.FONT_HERSHEY_SIMPLEX, 0.35,TEXT_COLOR, lineType=cv2.LINE_AA)
    return img

def visualize(annotations, category_id_to_name):
    img = annotations['image'].copy()
    for idx, bbox in enumerate(annotations['bboxes']):
        img = visualize_bbox(img, bbox, annotations['category_id'][idx], category_id_to_name)
    plt.figure(figsize=(18, 32))
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
def get_aug(aug, min_area=0., min_visibility=0.):
       return Compose(aug, bbox_params=BboxParams(format='pascal_voc', min_area=min_area, min_visibility=min_visibility, label_fields=['category_id']))

# %%
doc_aug = [
    A.RandomCrop(p=0.5,height=200,width=200),
    A.RandomBrightnessContrast(p=0.6),
    A.Rotate(limit=10, p=0.3),
    A.VerticalFlip(p=0.2),
    A.HorizontalFlip(p=0.2),
]

# %%
category_id_to_name = {0:'avocado',1:'banana'}

# %%
# By geaxgx
xml_body_1="""<annotation>
        <folder>FOLDER</folder>
        <filename>{FILENAME}</filename>
        <path>{PATH}</path>
        <source>
                <database>Unknown</database>
        </source>
        <size>
                <width>{WIDTH}</width>
                <height>{HEIGHT}</height>
                <depth>3</depth>
        </size>
"""
xml_object=""" <object>
                <name>{CLASS}</name>
                <pose>Unspecified</pose>
                <truncated>0</truncated>
                <difficult>0</difficult>
                <bndbox>
                        <xmin>{XMIN}</xmin>
                        <ymin>{YMIN}</ymin>
                        <xmax>{XMAX}</xmax>
                        <ymax>{YMAX}</ymax>
                </bndbox>
        </object>
"""
xml_body_2="""</annotation>        
"""

def save_to_voc(imgFile, xmlFile, aug, w, h):
    with open(xmlFile,"w") as f:
        f.write(xml_body_1.format(**{'FILENAME':os.path.basename(imgFile), 'PATH':imgFile,'WIDTH':w,'HEIGHT':h}))
        for i,bb in enumerate(aug['bboxes']):            
            f.write(xml_object.format(**{'CLASS':category_id_to_name[aug['category_id'][i]],'XMIN':int(aug['bboxes'][i][0]),'YMIN':int(aug['bboxes'][i][1]),'XMAX':int(aug['bboxes'][i][2]),'YMAX':int(aug['bboxes'][i][3])}))
        f.write(xml_body_2)

# %%
albumentationsError=0
datasetFolder=r'C:\Users\choowilson\Desktop\train'
for root, dirs, files in os.walk(datasetFolder):
    for file in files:
        if file.endswith(".jpg"):
            imageFile = osp.join(root,file)
            xmlFile = osp.join(root,file[:-4]+".xml")
            print(imageFile)
            print(xmlFile)
            print("")
            objects=[]
            classIds=[]
            objects , classIds = getObjects(xmlFile)
            image = cv2.imread(imageFile)
            annotations = {'image':image,'bboxes':objects,'category_id':classIds}
#             Generate how many augmented images for each image
            for i in range(2):
                try:
                    aug = get_aug(doc_aug)
                    augmented = aug(**annotations)
                    aug_h = augmented['image'].shape[0]
                    aug_w = augmented['image'].shape[1]
                    save_to_voc(f"{file[:-4]}_aug_{i}.jpg",f"{file[:-4]}_aug_{i}.xml",augmented,aug_w,aug_h)
                    cv2.imwrite(f"{file[:-4]}_aug_{i}.jpg",augmented['image'])
                except Exception as e:
                    print(e)
                    albumentationsError+=1
# Out:
# C:\Users\choowilson\Desktop\train\a1.jpg
# C:\Users\choowilson\Desktop\train\a1.xml
#
# C:\Users\choowilson\Desktop\train\a10.jpg
# C:\Users\choowilson\Desktop\train\a10.xml
#
# Requested crop size (200, 200) is larger than the image size (199, 300)
# Requested crop size (200, 200) is larger than the image size (199, 300)
# C:\Users\choowilson\Desktop\train\a11.jpg
# C:\Users\choowilson\Desktop\train\a11.xml
#
# C:\Users\choowilson\Desktop\train\a12.jpg
# C:\Users\choowilson\Desktop\train\a12.xml
#
# C:\Users\choowilson\Desktop\train\a13.jpg
# C:\Users\choowilson\Desktop\train\a13.xml
#
# Requested crop size (200, 200) is larger than the image size (176, 300)
# C:\Users\choowilson\Desktop\train\a14.jpg
# C:\Users\choowilson\Desktop\train\a14.xml
#
# C:\Users\choowilson\Desktop\train\a15.jpg
# C:\Users\choowilson\Desktop\train\a15.xml
#
# C:\Users\choowilson\Desktop\train\a16.jpg
# C:\Users\choowilson\Desktop\train\a16.xml
#
# C:\Users\choowilson\Desktop\train\a17.jpg
# C:\Users\choowilson\Desktop\train\a17.xml
#
# C:\Users\choowilson\Desktop\train\a18.jpg
# C:\Users\choowilson\Desktop\train\a18.xml
#
# C:\Users\choowilson\Desktop\train\a19.jpg
# C:\Users\choowilson\Desktop\train\a19.xml
#
# C:\Users\choowilson\Desktop\train\a2.jpg
# C:\Users\choowilson\Desktop\train\a2.xml
#
# C:\Users\choowilson\Desktop\train\a20.jpg
# C:\Users\choowilson\Desktop\train\a20.xml
#
# C:\Users\choowilson\Desktop\train\a21.jpg
# C:\Users\choowilson\Desktop\train\a21.xml
#
# Requested crop size (200, 200) is larger than the image size (177, 300)
# Requested crop size (200, 200) is larger than the image size (177, 300)
# C:\Users\choowilson\Desktop\train\a22.jpg
# C:\Users\choowilson\Desktop\train\a22.xml
#
# C:\Users\choowilson\Desktop\train\a23.jpg
# C:\Users\choowilson\Desktop\train\a23.xml
#
# C:\Users\choowilson\Desktop\train\a24.jpg
# C:\Users\choowilson\Desktop\train\a24.xml
#
# C:\Users\choowilson\Desktop\train\a25.jpg
# C:\Users\choowilson\Desktop\train\a25.xml
#
# Requested crop size (200, 200) is larger than the image size (187, 300)
# C:\Users\choowilson\Desktop\train\a26.jpg
# C:\Users\choowilson\Desktop\train\a26.xml
#
# C:\Users\choowilson\Desktop\train\a27.jpg
# C:\Users\choowilson\Desktop\train\a27.xml
#
# C:\Users\choowilson\Desktop\train\a28.jpg
# C:\Users\choowilson\Desktop\train\a28.xml
#
# C:\Users\choowilson\Desktop\train\a29.jpg
# C:\Users\choowilson\Desktop\train\a29.xml
#
# C:\Users\choowilson\Desktop\train\a3.jpg
# C:\Users\choowilson\Desktop\train\a3.xml
#
# C:\Users\choowilson\Desktop\train\a30.jpg
# C:\Users\choowilson\Desktop\train\a30.xml
#
# C:\Users\choowilson\Desktop\train\a4.jpg
# C:\Users\choowilson\Desktop\train\a4.xml
#
# C:\Users\choowilson\Desktop\train\a5.jpg
# C:\Users\choowilson\Desktop\train\a5.xml
#
# C:\Users\choowilson\Desktop\train\a6.jpg
# C:\Users\choowilson\Desktop\train\a6.xml
#
# C:\Users\choowilson\Desktop\train\a7.jpg
# C:\Users\choowilson\Desktop\train\a7.xml
#
# C:\Users\choowilson\Desktop\train\a8.jpg
# C:\Users\choowilson\Desktop\train\a8.xml
#
# C:\Users\choowilson\Desktop\train\a9.jpg
# C:\Users\choowilson\Desktop\train\a9.xml
#
# C:\Users\choowilson\Desktop\train\avcd0.jpg
# C:\Users\choowilson\Desktop\train\avcd0.xml
#
# C:\Users\choowilson\Desktop\train\avcd1.jpg
# C:\Users\choowilson\Desktop\train\avcd1.xml
#
# C:\Users\choowilson\Desktop\train\avcd10.jpg
# C:\Users\choowilson\Desktop\train\avcd10.xml
#
# C:\Users\choowilson\Desktop\train\avcd11.jpg
# C:\Users\choowilson\Desktop\train\avcd11.xml
#
# C:\Users\choowilson\Desktop\train\avcd12.jpg
# C:\Users\choowilson\Desktop\train\avcd12.xml
#
# C:\Users\choowilson\Desktop\train\avcd13.jpg
# C:\Users\choowilson\Desktop\train\avcd13.xml
#
# C:\Users\choowilson\Desktop\train\avcd14.jpg
# C:\Users\choowilson\Desktop\train\avcd14.xml
#
#
# C:\Users\choowilson\Desktop\train\b26.jpg
# C:\Users\choowilson\Desktop\train\b26.xml
#
# C:\Users\choowilson\Desktop\train\b27.jpg
# C:\Users\choowilson\Desktop\train\b27.xml
#
# C:\Users\choowilson\Desktop\train\b28.jpg
# C:\Users\choowilson\Desktop\train\b28.xml
#
# C:\Users\choowilson\Desktop\train\b29.jpg
# C:\Users\choowilson\Desktop\train\b29.xml
#
# C:\Users\choowilson\Desktop\train\b3.jpg
# C:\Users\choowilson\Desktop\train\b3.xml
#
# C:\Users\choowilson\Desktop\train\b30.jpg
# C:\Users\choowilson\Desktop\train\b30.xml
#
# C:\Users\choowilson\Desktop\train\b4.jpg
# C:\Users\choowilson\Desktop\train\b4.xml
#
# C:\Users\choowilson\Desktop\train\b5.jpg
# C:\Users\choowilson\Desktop\train\b5.xml
#
# C:\Users\choowilson\Desktop\train\b6.jpg
# C:\Users\choowilson\Desktop\train\b6.xml
#
# C:\Users\choowilson\Desktop\train\b7.jpg
# C:\Users\choowilson\Desktop\train\b7.xml
#
# C:\Users\choowilson\Desktop\train\b8.jpg
# C:\Users\choowilson\Desktop\train\b8.xml
#
# C:\Users\choowilson\Desktop\train\b9.jpg
# C:\Users\choowilson\Desktop\train\b9.xml
#
# C:\Users\choowilson\Desktop\train\ban4.jpg
# C:\Users\choowilson\Desktop\train\ban4.xml
#
# C:\Users\choowilson\Desktop\train\ban5.jpg
# C:\Users\choowilson\Desktop\train\ban5.xml
#
# C:\Users\choowilson\Desktop\train\ban6.jpg
# C:\Users\choowilson\Desktop\train\ban6.xml
#
# C:\Users\choowilson\Desktop\train\ban7.jpg
# C:\Users\choowilson\Desktop\train\ban7.xml
#
# C:\Users\choowilson\Desktop\train\ban8.jpg
# C:\Users\choowilson\Desktop\train\ban8.xml
#
# C:\Users\choowilson\Desktop\train\bana2.jpg
# C:\Users\choowilson\Desktop\train\bana2.xml
#
# C:\Users\choowilson\Desktop\train\bana4.jpg
# C:\Users\choowilson\Desktop\train\bana4.xml
#
# C:\Users\choowilson\Desktop\train\banan3.jpg
# C:\Users\choowilson\Desktop\train\banan3.xml
#
# C:\Users\choowilson\Desktop\train\banana-13266521.jpg
# C:\Users\choowilson\Desktop\train\banana-13266521.xml
#
# C:\Users\choowilson\Desktop\train\banana-16827437.jpg
# C:\Users\choowilson\Desktop\train\banana-16827437.xml
#
# C:\Users\choowilson\Desktop\train\banana-16904821.jpg
# C:\Users\choowilson\Desktop\train\banana-16904821.xml
#
# C:\Users\choowilson\Desktop\train\banana-17421486.jpg
# C:\Users\choowilson\Desktop\train\banana-17421486.xml
#
# C:\Users\choowilson\Desktop\train\banana-18299223.jpg
# C:\Users\choowilson\Desktop\train\banana-18299223.xml
#
# C:\Users\choowilson\Desktop\train\banana-22373200.jpg
# C:\Users\choowilson\Desktop\train\banana-22373200.xml
#
# C:\Users\choowilson\Desktop\train\banana-23421798.jpg
# C:\Users\choowilson\Desktop\train\banana-23421798.xml
#
# C:\Users\choowilson\Desktop\train\banana-26747283.jpg
# C:\Users\choowilson\Desktop\train\banana-26747283.xml
#
# C:\Users\choowilson\Desktop\train\banana-29017344.jpg
# C:\Users\choowilson\Desktop\train\banana-29017344.xml
#
# C:\Users\choowilson\Desktop\train\banana-4680760.jpg
# C:\Users\choowilson\Desktop\train\banana-4680760.xml
#
# C:\Users\choowilson\Desktop\train\banana-7824462.jpg
# C:\Users\choowilson\Desktop\train\banana-7824462.xml
#
# C:\Users\choowilson\Desktop\train\banana-bunch-17358205.jpg
# C:\Users\choowilson\Desktop\train\banana-bunch-17358205.xml
#
# C:\Users\choowilson\Desktop\train\banana-chips-37859218.jpg
# C:\Users\choowilson\Desktop\train\banana-chips-37859218.xml
#
# C:\Users\choowilson\Desktop\train\banana0.jpg
# C:\Users\choowilson\Desktop\train\banana0.xml
#
# C:\Users\choowilson\Desktop\train\banana2.jpg
# C:\Users\choowilson\Desktop\train\banana2.xml
#
# C:\Users\choowilson\Desktop\train\banana8.jpg
# C:\Users\choowilson\Desktop\train\banana8.xml
#
# C:\Users\choowilson\Desktop\train\banana9.jpg
# C:\Users\choowilson\Desktop\train\banana9.xml
#
# C:\Users\choowilson\Desktop\train\bananaa.jpg
# C:\Users\choowilson\Desktop\train\bananaa.xml
#
# C:\Users\choowilson\Desktop\train\bananan5.jpg
# C:\Users\choowilson\Desktop\train\bananan5.xml
#
# C:\Users\choowilson\Desktop\train\bananana.jpg
# C:\Users\choowilson\Desktop\train\bananana.xml
#
# C:\Users\choowilson\Desktop\train\banananana.jpg
# C:\Users\choowilson\Desktop\train\banananana.xml
#
# C:\Users\choowilson\Desktop\train\bnana.jpg
# C:\Users\choowilson\Desktop\train\bnana.xml
#
# C:\Users\choowilson\Desktop\train\bnana1.jpg
# C:\Users\choowilson\Desktop\train\bnana1.xml
#
# C:\Users\choowilson\Desktop\train\bnana3.jpg
# C:\Users\choowilson\Desktop\train\bnana3.xml
#
# C:\Users\choowilson\Desktop\train\bnana4.jpg
# C:\Users\choowilson\Desktop\train\bnana4.xml
#
# C:\Users\choowilson\Desktop\train\bnana5.jpg
# C:\Users\choowilson\Desktop\train\bnana5.xml
#
# C:\Users\choowilson\Desktop\train\bnana6.jpg
# C:\Users\choowilson\Desktop\train\bnana6.xml
#
# C:\Users\choowilson\Desktop\train\bnana7.jpg
# C:\Users\choowilson\Desktop\train\bnana7.xml
#
# C:\Users\choowilson\Desktop\train\bnana8.jpg
# C:\Users\choowilson\Desktop\train\bnana8.xml
#
# C:\Users\choowilson\Desktop\train\bnn1.jpg
# C:\Users\choowilson\Desktop\train\bnn1.xml
#
# C:\Users\choowilson\Desktop\train\bnn2.jpg
# C:\Users\choowilson\Desktop\train\bnn2.xml
#
# C:\Users\choowilson\Desktop\train\bnn20.jpg
# C:\Users\choowilson\Desktop\train\bnn20.xml
#
# C:\Users\choowilson\Desktop\train\bnn5.jpg
# C:\Users\choowilson\Desktop\train\bnn5.xml
#
# C:\Users\choowilson\Desktop\train\bnn50.jpg
# C:\Users\choowilson\Desktop\train\bnn50.xml
#
# C:\Users\choowilson\Desktop\train\bnn6.jpg
# C:\Users\choowilson\Desktop\train\bnn6.xml
#
# C:\Users\choowilson\Desktop\train\bnn9.jpg
# C:\Users\choowilson\Desktop\train\bnn9.xml
#
# C:\Users\choowilson\Desktop\train\bnna1.jpg
# C:\Users\choowilson\Desktop\train\bnna1.xml
#
# C:\Users\choowilson\Desktop\train\bnna10.jpg
# C:\Users\choowilson\Desktop\train\bnna10.xml
#
# C:\Users\choowilson\Desktop\train\bnna11.jpg
# C:\Users\choowilson\Desktop\train\bnna11.xml
#
# C:\Users\choowilson\Desktop\train\bnna12.jpg
# C:\Users\choowilson\Desktop\train\bnna12.xml
#
# C:\Users\choowilson\Desktop\train\bnna13.jpg
# C:\Users\choowilson\Desktop\train\bnna13.xml
#
# C:\Users\choowilson\Desktop\train\bnna14.jpg
# C:\Users\choowilson\Desktop\train\bnna14.xml
#
# C:\Users\choowilson\Desktop\train\bnna15.jpg
# C:\Users\choowilson\Desktop\train\bnna15.xml
#
# C:\Users\choowilson\Desktop\train\bnna16.jpg
# C:\Users\choowilson\Desktop\train\bnna16.xml
#
# C:\Users\choowilson\Desktop\train\bnna17.jpg
# C:\Users\choowilson\Desktop\train\bnna17.xml
#
# C:\Users\choowilson\Desktop\train\bnna18.jpg
# C:\Users\choowilson\Desktop\train\bnna18.xml
#
# C:\Users\choowilson\Desktop\train\bnna19.jpg
# C:\Users\choowilson\Desktop\train\bnna19.xml
#
# C:\Users\choowilson\Desktop\train\bnna2.jpg
# C:\Users\choowilson\Desktop\train\bnna2.xml
#
# C:\Users\choowilson\Desktop\train\bnna20.jpg
# C:\Users\choowilson\Desktop\train\bnna20.xml
#
# C:\Users\choowilson\Desktop\train\bnna21.jpg
# C:\Users\choowilson\Desktop\train\bnna21.xml
#
# C:\Users\choowilson\Desktop\train\bnna22.jpg
# C:\Users\choowilson\Desktop\train\bnna22.xml
# C:\Users\choowilson\Desktop\train\bnna23.jpg
# C:\Users\choowilson\Desktop\train\bnna23.xml
#
# C:\Users\choowilson\Desktop\train\bnna3.jpg
# C:\Users\choowilson\Desktop\train\bnna3.xml
#
# C:\Users\choowilson\Desktop\train\bnna4.jpg
# C:\Users\choowilson\Desktop\train\bnna4.xml
#
# C:\Users\choowilson\Desktop\train\bnna5.jpg
# C:\Users\choowilson\Desktop\train\bnna5.xml
#
# C:\Users\choowilson\Desktop\train\bnna6.jpg
# C:\Users\choowilson\Desktop\train\bnna6.xml
#
# C:\Users\choowilson\Desktop\train\bnna7.jpg
# C:\Users\choowilson\Desktop\train\bnna7.xml
#
# C:\Users\choowilson\Desktop\train\bnna8.jpg
# C:\Users\choowilson\Desktop\train\bnna8.xml
#
# C:\Users\choowilson\Desktop\train\bnna9.jpg
# C:\Users\choowilson\Desktop\train\bnna9.xml
#
# C:\Users\choowilson\Desktop\train\bnnn1.jpg
# C:\Users\choowilson\Desktop\train\bnnn1.xml
#
# C:\Users\choowilson\Desktop\train\bnnn2.jpg
# C:\Users\choowilson\Desktop\train\bnnn2.xml
#
# C:\Users\choowilson\Desktop\train\man-banana-24257122.jpg
# C:\Users\choowilson\Desktop\train\man-banana-24257122.xml

# %%
print(albumentationsError)
# Out:
# 6
